# %%
import pandas as pd

# %%
cbo = pd.read_csv('br_bd_diretorios_brasil_cbo_2002.csv')

# %%
cbo.head()
# Out:
#   cbo_2002                       descricao  familia  \
# 0   010105  Oficial General Da Aeronáutica      101
# 1   010110     Oficial General Do Exército      101
# 2   010115      Oficial General Da Marinha      101
# 3   010210             Oficial Do Exército      102
# 4   010205          Oficial Da Aeronáutica      102
#
#                       descricao_familia  subgrupo  \
# 0  Oficiais generais das forças armadas        10
# 1  Oficiais generais das forças armadas        10
# 2  Oficiais generais das forças armadas        10
# 3           Oficiais das forças armadas        10
# 4           Oficiais das forças armadas        10
#
#                                   descricao_subgrupo  subgrupo_principal  \
# 0  Membros Das Forças Armadas                    ...                   1
# 1  Membros Das Forças Armadas                    ...                   1
# 2  Membros Das Forças Armadas                    ...                   1
# ...

# %%
cbo_filtragem_1 = cbo[(cbo['familia'] == 1425)]

# %%
cbo_filtragem_1.shape
# Out:
# (7, 11)

# %%
cbo_filtragem_1.head(11)
# Out:
#     cbo_2002                                          descricao  familia  \
# 174   142520    Gerente De Projetos De Tecnologia Da Informação     1425
# 175   142530  Gerente De Suporte Técnico De Tecnologia Da In...     1425
# 176   142505  Gerente De Infraestrutura De Tecnologia Da Inf...     1425
# 177   142525                 Gerente De Segurança Da Informação     1425
# 178   142535    Tecnólogo Em Gestão Da Tecnologia Da Informação     1425
# 179   142510             Gerente De Desenvolvimento De Sistemas     1425
# 180   142515    Gerente De Operação De Tecnologia Da Informação     1425
#
#                         descricao_familia  subgrupo  \
# 174  Gerentes de tecnologia da informação       142
# 175  Gerentes de tecnologia da informação       142
# 176  Gerentes de tecnologia da informação       142
# 177  Gerentes de tecnologia da informação       142
# 178  Gerentes de tecnologia da informação       142
# 179  Gerentes de tecnologia da informação       142
# ...
